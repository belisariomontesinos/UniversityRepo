# %% [markdown]
# ## This Is Belisario's Notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uni = pd.read_csv('/Users/belisariomontesinos/Documents/universities.csv')

# %%
uni.head
# Out:
# <bound method NDFrame.head of                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# ...

# %%
uni.info
# Out:
# <bound method DataFrame.info of                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# ...

# %%
unitypemean = uni.groupby('Type')['Size'].agg('mean')
utypemean = pd.DataFrame(unitypemean)
utypemean.sort_values(by = 'Size')
# Out:
#                                                             Size
# Type
# 4-year, primarily associate's, Private for-profit     934.380597
# 4-year, primarily associate's, Private not-for-...   1129.413793
# 4-year, Private not-for-profit                       2399.885696
# 4-year, Private for-profit                           3504.501859
# 4-year, primarily associate's, Public                6889.366197
# 4-year, Public                                      11478.913765

# %%
unitypemed = uni.groupby('Type')['Size'].agg('median')
utypemed = pd.DataFrame(unitypemed)
utypemed.sort_values(by = 'Size')
# Out:
#                                                       Size
# Type
# 4-year, primarily associate's, Private for-profit    564.5
# 4-year, Private for-profit                           730.0
# 4-year, primarily associate's, Private not-for-...   768.0
# 4-year, Private not-for-profit                      1206.0
# 4-year, primarily associate's, Public               3558.0
# 4-year, Public                                      7669.0

# %%
addy = uni['address']
addy
# Out:
# 0             800 W Jefferson, Kirksville, Missouri 63501
# 1                 1600 Campus Court, Abilene, Texas 79699
# 2              2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3       1101 E. 78th Street, Suite 100, Minneapolis, M...
# 4              305 SE 2nd Ave, Gainesville, Florida 32601
#                               ...
# 2902    13315 W. Washington Boulevard, Los Angeles, Ca...
# 2903             1125 E 8th St, York, Nebraska 68467-2699
# 2904       Country Club Rd, York, Pennsylvania 17403-3651
# 2905    One University Plaza, Youngstown, Ohio 44555-0001
# 2906    320 South Main Street, Haverhill, Massachusett...
# Name: address, Length: 2907, dtype: object

# %%
addy = addy.str.split(',', expand=True)
type(addy)
# Out:
# pandas.core.frame.DataFrame

# %%
city = addy
city = city[1]
city
# Out:
# 0         Kirksville
# 1            Abilene
# 2             Tifton
# 3          Suite 100
# 4        Gainesville
#             ...
# 2902     Los Angeles
# 2903            York
# 2904            York
# 2905      Youngstown
# 2906       Haverhill
# Name: 1, Length: 2907, dtype: object

# %%
addy['City'] = city
addy
# Out:
#                                   0             1                         2  \
# 0                   800 W Jefferson    Kirksville            Missouri 63501
# 1                 1600 Campus Court       Abilene               Texas 79699
# 2                    2802 Moore Hwy        Tifton        Georgia 31793-2601
# 3               1101 E. 78th Street     Suite 100               Minneapolis
# 4                    305 SE 2nd Ave   Gainesville             Florida 32601
# ...                             ...           ...                       ...
# 2902  13315 W. Washington Boulevard   Los Angeles          California 90066
# 2903                  1125 E 8th St          York       Nebraska 68467-2699
# 2904                Country Club Rd          York   Pennsylvania 17403-3651
# 2905           One University Plaza    Youngstown           Ohio 44555-0001
# 2906          320 South Main Street     Haverhill       Massachusetts 01835
#
#                           3     4     5          City
# ...

# %%
zipstate = addy[2]
zipstate
# Out:
# 0                 Missouri 63501
# 1                    Texas 79699
# 2             Georgia 31793-2601
# 3                    Minneapolis
# 4                  Florida 32601
#                   ...
# 2902            California 90066
# 2903         Nebraska 68467-2699
# 2904     Pennsylvania 17403-3651
# 2905             Ohio 44555-0001
# 2906         Massachusetts 01835
# Name: 2, Length: 2907, dtype: object

# %%
zipstate = zipstate.str.split(' ', expand=True)
zipstate
# Out:
#      0               1           2     3     4     5
# 0             Missouri       63501  None  None  None
# 1                Texas       79699  None  None  None
# 2              Georgia  31793-2601  None  None  None
# 3          Minneapolis        None  None  None  None
# 4              Florida       32601  None  None  None
# ...  ..            ...         ...   ...   ...   ...
# 2902        California       90066  None  None  None
# 2903          Nebraska  68467-2699  None  None  None
# 2904      Pennsylvania  17403-3651  None  None  None
# 2905              Ohio  44555-0001  None  None  None
# 2906     Massachusetts       01835  None  None  None
#
# [2907 rows x 6 columns]

# %%
state = zipstate[1]
state
# Out:
# 0            Missouri
# 1               Texas
# 2             Georgia
# 3         Minneapolis
# 4             Florida
#             ...
# 2902       California
# 2903         Nebraska
# 2904     Pennsylvania
# 2905             Ohio
# 2906    Massachusetts
# Name: 1, Length: 2907, dtype: object

# %%
addy['State'] = state
addy
# Out:
#                                   0             1                         2  \
# 0                   800 W Jefferson    Kirksville            Missouri 63501
# 1                 1600 Campus Court       Abilene               Texas 79699
# 2                    2802 Moore Hwy        Tifton        Georgia 31793-2601
# 3               1101 E. 78th Street     Suite 100               Minneapolis
# 4                    305 SE 2nd Ave   Gainesville             Florida 32601
# ...                             ...           ...                       ...
# 2902  13315 W. Washington Boulevard   Los Angeles          California 90066
# 2903                  1125 E 8th St          York       Nebraska 68467-2699
# 2904                Country Club Rd          York   Pennsylvania 17403-3651
# 2905           One University Plaza    Youngstown           Ohio 44555-0001
# 2906          320 South Main Street     Haverhill       Massachusetts 01835
#
# ...

# %%
zipstate = zipstate[2]
zipstate
# Out:
# 0            63501
# 1            79699
# 2       31793-2601
# 3             None
# 4            32601
#            ...
# 2902         90066
# 2903    68467-2699
# 2904    17403-3651
# 2905    44555-0001
# 2906         01835
# Name: 2, Length: 2907, dtype: object

# %%
zipstate = zipstate.str.split('-', expand=True)
zipstate
# Out:
#           0     1
# 0     63501  None
# 1     79699  None
# 2     31793  2601
# 3      None  None
# 4     32601  None
# ...     ...   ...
# 2902  90066  None
# 2903  68467  2699
# 2904  17403  3651
# 2905  44555  0001
# 2906  01835  None
#
# [2907 rows x 2 columns]

# %%
zipcode = zipstate[0]
zipcode
# Out:
# 0       63501
# 1       79699
# 2       31793
# 3        None
# 4       32601
#         ...
# 2902    90066
# 2903    68467
# 2904    17403
# 2905    44555
# 2906    01835
# Name: 0, Length: 2907, dtype: object

# %%
addy['ZipCode'] = zipcode
addy
# Out:
#                                   0             1                         2  \
# 0                   800 W Jefferson    Kirksville            Missouri 63501
# 1                 1600 Campus Court       Abilene               Texas 79699
# 2                    2802 Moore Hwy        Tifton        Georgia 31793-2601
# 3               1101 E. 78th Street     Suite 100               Minneapolis
# 4                    305 SE 2nd Ave   Gainesville             Florida 32601
# ...                             ...           ...                       ...
# 2902  13315 W. Washington Boulevard   Los Angeles          California 90066
# 2903                  1125 E 8th St          York       Nebraska 68467-2699
# 2904                Country Club Rd          York   Pennsylvania 17403-3651
# 2905           One University Plaza    Youngstown           Ohio 44555-0001
# 2906          320 South Main Street     Haverhill       Massachusetts 01835
#
# ...

# %%
ptype = uni['Type']
ptype = ptype.str.strip()
ptype = ptype.str.split(',', expand=True)
ptype
#ptype = ptype.astype(str)
# Out:
#            0                        1                    2
# 0     4-year   Private not-for-profit                 None
# 1     4-year   Private not-for-profit                 None
# 2     4-year    primarily associate's               Public
# 3     4-year    primarily associate's   Private for-profit
# 4     4-year   Private not-for-profit                 None
# ...      ...                      ...                  ...
# 2902  4-year   Private not-for-profit                 None
# 2903  4-year   Private not-for-profit                 None
# 2904  4-year   Private not-for-profit                 None
# 2905  4-year                   Public                 None
# 2906  4-year   Private not-for-profit                 None
#
# [2907 rows x 3 columns]

# %%
associates = []
for i in ptype[1]:
    if 'primarily' in i:
        associates.append(1)
    elif 'primarily' not in i:
        associates.append(0)
    else:
        associates.append(0)

# %%
uni['Associates'] = associates

# %%
adds = addy[addy.columns[6:9]]
type(adds)
# Out:
# pandas.core.frame.DataFrame

# %%
adds
# Out:
#               City          State ZipCode
# 0       Kirksville       Missouri   63501
# 1          Abilene          Texas   79699
# 2           Tifton        Georgia   31793
# 3        Suite 100    Minneapolis    None
# 4      Gainesville        Florida   32601
# ...            ...            ...     ...
# 2902   Los Angeles     California   90066
# 2903          York       Nebraska   68467
# 2904          York   Pennsylvania   17403
# 2905    Youngstown           Ohio   44555
# 2906     Haverhill  Massachusetts   01835
#
# [2907 rows x 3 columns]

# %%
city = adds['City']
state = adds['State']
zipcode = adds['ZipCode']

# %%
uni['City'] = city
uni['State'] = state
uni['Zipcode'] = zipcode

# %%
uni
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
pub = uni['Type']
pub = pub.str.strip()
pub = pub.str.split(',', expand=True)
pub
# Out:
#            0                        1                    2
# 0     4-year   Private not-for-profit                 None
# 1     4-year   Private not-for-profit                 None
# 2     4-year    primarily associate's               Public
# 3     4-year    primarily associate's   Private for-profit
# 4     4-year   Private not-for-profit                 None
# ...      ...                      ...                  ...
# 2902  4-year   Private not-for-profit                 None
# 2903  4-year   Private not-for-profit                 None
# 2904  4-year   Private not-for-profit                 None
# 2905  4-year                   Public                 None
# 2906  4-year   Private not-for-profit                 None
#
# [2907 rows x 3 columns]

# %%
public = []
private = []

for i in pub[1]:
    if 'Public' in i:
        public.append('Public')
    elif 'Public' not in i:
        public.append('Private')
    else:
        public.append('Private')

# %%
uni['Priv or Pub'] = public
uni
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
notfor = []

for i in pub[1]:
    if 'not' in i:
        notfor.append('not-for-profit')
    elif 'private' not in i:
        notfor.append('public')
    else:
        notfor.append('for-profit')

# %%
uni['for-profit or not-for-profit'] = notfor
uni
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
statemed = uni.groupby('State')['Size'].agg('median')
statemed = pd.DataFrame(statemed)
statemed.sort_values(by = 'Size')
# Out:
#              Size
# State
# Gainesville  36.0
# Brattleboro  42.0
# Evanston     57.0
# Clive        61.0
# Wilberforce  82.0
# ...           ...
# Overland      NaN
# Roseville     NaN
# Seattle       NaN
# Selma         NaN
# Traverse      NaN
#
# [163 rows x 1 columns]

# %%
statemean = uni.groupby('State')['Size'].agg('mean')
statemean = pd.DataFrame(statemean)
statemean.sort_values(by = 'Size')
# Out:
#              Size
# State
# Gainesville  36.0
# Brattleboro  42.0
# Evanston     57.0
# Clive        61.0
# Wilberforce  82.0
# ...           ...
# Overland      NaN
# Roseville     NaN
# Seattle       NaN
# Selma         NaN
# Traverse      NaN
#
# [163 rows x 1 columns]

# %%
citymean = uni.groupby('City')['Size'].agg('mean')
citymean = pd.DataFrame(citymean)
citymean.sort_values(by = 'Size')
# Out:
#                   Size
# City
#  Harvey            7.0
#  Blue Bell        11.0
#  Suffern          17.0
#  Kosciusko        19.0
#  West Des Moines  24.0
# ...                ...
#  Suite B-20        NaN
#  Suite B1          NaN
#  Unit 5            NaN
#  Vancouver         NaN
#  Warren            NaN
#
# [1454 rows x 1 columns]

# %%
citymed = uni.groupby('City')['Size'].agg('median')
citymed = pd.DataFrame(citymed)
citymed.sort_values(by = 'Size')
# Out:
#                   Size
# City
#  Harvey            7.0
#  Blue Bell        11.0
#  Suffern          17.0
#  Kosciusko        19.0
#  West Des Moines  24.0
# ...                ...
#  Suite B-20        NaN
#  Suite B1          NaN
#  Unit 5            NaN
#  Vancouver         NaN
#  Warren            NaN
#
# [1454 rows x 1 columns]

# %%
#privatemean = uni.groupby('Priv or Pub')['Size'].agg({'Private_Public': ['mean', 'median']})
privatemean = uni.groupby('Priv or Pub')['Size'].agg('mean')
privatemean = pd.DataFrame(privatemean)
privatemean.sort_values(by = 'Size')
#({'total_bill': ['count', 'mean', 'sum']})
# Out:
#                      Size
# Priv or Pub
# Private       2450.473495
# Public       11478.913765

# %%
privatemed = uni.groupby('Priv or Pub')['Size'].agg('median')
privatemed = pd.DataFrame(privatemed)
privatemed.sort_values(by = 'Size')
# Out:
#                Size
# Priv or Pub
# Private       986.0
# Public       7669.0

# %%
Ascmean = uni.groupby('Associates')['Size'].agg('mean')
Ascmean = pd.DataFrame(Ascmean)
Ascmean.sort_values(by = 'Size')
# Out:
#                    Size
# Associates
# 1           1966.708920
# 0           4801.798169

# %%
Ascmed = uni.groupby('Associates')['Size'].agg('median')
Ascmed = pd.DataFrame(Ascmed)
Ascmed.sort_values(by = 'Size')
# Out:
#               Size
# Associates
# 1            716.0
# 0           1727.0
